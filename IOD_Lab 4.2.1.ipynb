# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# ## Lab 4.2.1: Feature Selection

# %% [markdown]
# ### 1. Load & Explore Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# #### 1.1 Load Data

# %%
# Read CSV
wine_csv = 'winequality_merged.csv'
wine = pd.read_csv(wine_csv)
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# #### 1.2 Explore Data (Exploratory Data Analysis)

# %%
# ANSWER
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  red_wine
# 0      9.4        5         1
# ...

# %%
wine.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  red_wine
# ...

# %%
wine.shape
# Out:
# (6497, 13)

# %%
wine.dtypes
#red_wine == 1 (yes)
#red_wine == 0 (no, white wine?)
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# red_wine                  int64
# dtype: object

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  red_wine              6497 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 660.0 KB

# %%
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# red_wine                0
# dtype: int64

# %%
wine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219008     0.324436
# volatile acidity           0.219008          1.000000    -0.377981
# citric acid                0.324436         -0.377981     1.000000
# residual sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free sulfur dioxide       -0.282735         -0.352557     0.133126
# total sulfur dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# quality                   -0.076743         -0.265699     0.085532
# red_wine                   0.486740          0.653036    -0.187397
#
# ...

# %% [markdown]
# ### 2. Set Target Variable

# %% [markdown]
# Create a target variable for wine quality.

# %%
# Target Variable - 1D array
y = wine['quality']
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 6492    6
# 6493    5
# 6494    6
# 6495    7
# 6496    6
# Name: quality, Length: 6497, dtype: int64

# %% [markdown]
# ### 3. Set Predictor Variables

# %% [markdown]
# Create a predictor matrix with variables of your choice. State your reason.

# %%
# Predictor matrix - 2D array
X = wine[['alcohol', 'free sulfur dioxide', 'pH']]
X
# Out:
#       alcohol  free sulfur dioxide    pH
# 0         9.4                 11.0  3.51
# 1         9.8                 25.0  3.20
# 2         9.8                 15.0  3.26
# 3         9.8                 17.0  3.16
# 4         9.4                 11.0  3.51
# ...       ...                  ...   ...
# 6492     11.2                 24.0  3.27
# 6493      9.6                 57.0  3.15
# 6494      9.4                 30.0  2.99
# 6495     12.8                 20.0  3.34
# 6496     11.8                 22.0  3.26
#
# [6497 rows x 3 columns]

# %% [markdown]
# ### 4. Using Linear Regression Create a Model and Test Score

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Train-Test Split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
# Create a model for Linear Regression
# Fit the model with the Training data
model = LinearRegression().fit(X_train, y_train)
print(model.intercept_)
print(model.coef_)

# Calculate the score (R^2 for Regression) for Training Data
print(model.score(X_train, y_train))

# Calculate the score (R^2 for Regression) for Testing Data
# Although you can use x_train and y_train to check the goodness of fit, this isn’t a best practice
#An unbiased estimation of the predictive performance of your model is based on test data
print(model.score(X_test, y_test))
# Out:
# 2.1292231717846484
# [ 0.35065756  0.00732633 -0.06677133]
# 0.22223019229336816
# 0.19222878929767462

# %% [markdown]
# ### BONUS: Cross validation

# %%
# Cross validation 
from sklearn.model_selection import KFold 
from sklearn.metrics import mean_squared_error

# %%
k_fold = KFold(n_splits=5, shuffle=True) #n_splits = no. of folds
train_scores = []
train_rmse = []
test_scores = []
test_rmse = []

for k, (train, test) in enumerate(k_fold.split(X)):
    print(k, train, test)
# Out:
# 0 [   0    2    3 ... 6494 6495 6496] [   1    4    9 ... 6485 6487 6492]
# 1 [   0    1    2 ... 6493 6494 6496] [   3    5    6 ... 6478 6489 6495]
# 2 [   0    1    2 ... 6494 6495 6496] [   7   10   15 ... 6484 6490 6493]
# 3 [   0    1    3 ... 6492 6493 6495] [   2   11   20 ... 6491 6494 6496]
# 4 [   1    2    3 ... 6494 6495 6496] [   0   13   16 ... 6454 6482 6486]

# %%
# Set up 5-fold cross validation 
#https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html#sklearn.model_selection.KFold
#https://www.youtube.com/watch?v=TIgfjmp-4BA&ab_channel=Udacity
#is a way to use "all" data for training and testing to enhance accuracy since there is tradeoff between train and test split

k_fold = KFold(n_splits=5, shuffle=True) #n_splits = no. of folds
train_scores = []
train_rmse = []
test_scores = []
test_rmse = []

regr = LinearRegression() #instantiate model object
#do this because everytime you write "LinearRegression()" it creates a new object and forgets what you previously fit

for k, (train, test) in enumerate(k_fold.split(X)):
    # use enumerate() anytime you need to use the count and an item in a loop
    # k_fold.split(data) returns generator object, so u use it in a for...in...statement
    
    # Get training and test sets for X and y
    Xtrain = X.loc[train]
    ytrain = y.loc[train]
    Xtest = X.loc[test]
    ytest = y.loc[test]
    
    # Fit model with training set
    model = regr.fit(Xtrain, ytrain)
    
    # Make predictions with training and test set
    ypred_train = regr.predict(Xtrain)
    ypred_test = regr.predict(Xtest)
    
    # Score R2 and RMSE on training and test sets and store in list
    train_scores.append(regr.score(Xtrain, ytrain))
    test_scores.append(regr.score(Xtest, ytest))
    train_rmse.append(mean_squared_error(ytrain, ypred_train))
    test_rmse.append(mean_squared_error(ytest, ypred_test))
    
# Create a metrics_df dataframe to display r2 and rmse scores
metrics_df = pd.DataFrame(list(zip(train_scores, test_scores, train_rmse, test_rmse)),
               columns =['train scores', 'test scores', 'train RMSE', 'test RMSE'])
metrics_df
# Out:
#    train scores  test scores  train RMSE  test RMSE
# 0      0.222787     0.190762    0.592661   0.616314
# 1      0.214231     0.224926    0.607819   0.555817
# 2      0.224163     0.183353    0.589903   0.627859
# 3      0.206173     0.250107    0.596213   0.603001
# 4      0.216717     0.215071    0.598757   0.592273

# %%
# Describe the metrics
metrics_df.describe()
# Out:
#        train scores  test scores  train RMSE  test RMSE
# count      5.000000     5.000000    5.000000   5.000000
# mean       0.216814     0.212844    0.597071   0.599053
# std        0.007239     0.026911    0.006891   0.027652
# min        0.206173     0.183353    0.589903   0.555817
# 25%        0.214231     0.190762    0.592661   0.592273
# 50%        0.216717     0.215071    0.596213   0.603001
# 75%        0.222787     0.224926    0.598757   0.616314
# max        0.224163     0.250107    0.607819   0.627859

# %% [markdown]
# ### 5. Feature Selection
#
# What's your score (R^2 for Regression) for Testing Data?
#
# How many feature have you selected? Can you improve your score by selecting different features?

# %% [markdown]
# **Please continue with Lab 4.2.2 with the same dataset.**

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
